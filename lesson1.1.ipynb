# %% [markdown]
# # Привет! 🙌
#
# Мы начинаем наше путешествие вместе с временными рядами ⏳. В этом модуле узнаешь:
# * Что такое временые ряды
# * Как проверить результат
# * Что такое метрики успеха (качества) и чем они отличаются

# %% [markdown]
# Приглашаю Тебя в Slack. [Здесь инструкция](https://bit.ly/3A5jnww) по Slack, рекомендуем уделить немного времени для Slack, чтобы в течение курса было проще ориентироваться.
#
# - ❓[#ts_module1](https://dw-coursesru.slack.com/archives/C032WB4VBSQ) - это место, где можно обратиться за помощью, поделиться опытом и помочь другим. Если у Тебя есть вопрос, то постарайся как можно точнее его сформулировать, лучше всего прислать screen с своим кодом и ошибкой, которая появилась.
#
# - 💪 [#ts_module1_done](https://dw-coursesru.slack.com/archives/C033HQ8BGSC) - в этот канал нужно отправлять (в виде скриншота) выполненные задания по первому модулю. Просьба все задания для одного урока отправлять в рамках одного своего сообщения и комментариев к нему:)
#
# - 🧠 [#ts_module1_ideas](https://dw-coursesru.slack.com/archives/C0336L2AZUZ) - это канал, где можно делиться своими мыслями и идеями, которые будут появляться при обучении на 1 модуле.
#
# - В канале [#networking](https://dw-coursesru.slack.com/archives/C02CZLJ95HD) расскажи немного о себе (откуда, чем занимаешься, чего ждешь от курса) и заодно познакомься с другими участниками курса. Как правило - студенты курса по Time Series - наши бывшие выпускники прошлых курсов 😉

# %% [markdown]
# ## E-book
# Для первого урока я подготовил первую часть своей авторской книги. Всего будет **6 частей** для каждого модуля.
# А по завершении курса Ты получишь итоговую версию книги, которая состоит из всех частей.
# Книга написана доступным языком, где я делюсь опытом, интересными фактами и наблюдениями.
# Я рекомендую прочитать эту книгу (она небольшая - **23 страницы** с учетом картинок 😉) перед тем, как перейти к следующему уроку.
#
# <a href="https://bit.ly/34vKnfd"><img src="../images/logo.png"></a>
#
# [Скачать](https://bit.ly/34vKnfd)
